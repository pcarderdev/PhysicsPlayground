# %%
import numpy as np
import matplotlib.pyplot as plt

x_vals = np.arange(0, 100)
y_vals = np.arange(0, 100)
z_vals = np.arange(0, 100)

eq1 = 3 * x_vals + 5 * y_vals - 2 * z_vals
eq2 = 6 * x_vals + 10 * y_vals - 4 * z_vals
eq3 = 3 * x_vals + 2 * y_vals - 9 * z_vals

plt.close()
plt.plot(x_vals, y_vals, eq1) 
plt.show()
